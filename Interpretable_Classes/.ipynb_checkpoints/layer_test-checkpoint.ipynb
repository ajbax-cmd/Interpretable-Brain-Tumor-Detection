# %% [markdown]
# # Evalualte Layer Feature Space Correlation with Model Output Using Pearson Correlation
# Images are not cropped to bounding box

# %%
import torch
import gc
import matplotlib.pyplot as plt
from yolov8_interpretable import InterpretableYOLOTest

def visualize_features(features, num_features=10):
    plt.figure(figsize=(15, 5))
    for i in range(num_features):
        plt.subplot(1, num_features, i + 1)
        plt.imshow(features[:, i].reshape(-1, 1), aspect='auto', cmap='viridis')
        plt.colorbar()
        plt.title(f'Feature {i+1}')
    plt.tight_layout()
    plt.show()

def evaluate_multiple_layers(data_yaml_path, weights_path, layer_indices, batch_size=1, img_size=(640, 640)):
    layer_scores = {}
    for layer_index in layer_indices:
        print(f"Evaluating layer at index: {layer_index}")
        weights = load_model(weights_path, model_class=None)
        model = InterpretableYOLOTest(data_yaml_path, weights, batch_size=batch_size, img_size=img_size, target_layer_index=layer_index)
        score = model.calculate_pearson_correlation()
        layer_scores[layer_index] = score
        
        # Visualize features for the first few samples
        visualize_features(model.features[:10, :])
        
        # Delete model and run garbage collection
        del model
        gc.collect()
    return layer_scores

def empirical_validation(model, directory_path, k=5):
    # Perform inference on all images in a directory
    results = model.iterate_directory_inference(directory_path, k)
    for result in results:
        print(result)
    return results

def load_model(model_path, model_class=None):
    # loading a custom model
    model = torch.load(model_path)
    model = model['model'].float()
    model.eval()  # Set the model to evaluation mode
    return model

def main():
    data = '/home/alan/Documents/Dataset_1/brain-tumor-detection-dataset/Br35H-Mask-RCNN/data.yaml'
    weights_path = '/home/alan/Documents/YOLOV8_interpretable/YOLOv8_weights/best.pt'
    weights = load_model(weights_path, model_class=None)
    
    # Evaluate layers at a broader range of indices
    layer_indices = list(range(100, 295, 20))  # every 20th layer
    layer_scores = evaluate_multiple_layers(data, weights_path, layer_indices)
    
    print("Layer Scores:")
    for layer_index, score in layer_scores.items():
        print(f"Layer {layer_index}: {score}")
    
    # Choose the best layer based on the scores
    best_layer_index = max(layer_scores, key=layer_scores.get)
    print(f"Best layer index: {best_layer_index} with score: {layer_scores[best_layer_index]}")
    
    # Create a model with the best layer
    best_model = InterpretableYOLOTest(data, weights, batch_size=1, img_size=(640, 640), target_layer_index=best_layer_index)
    
    # Perform empirical validation
    directory_path = '/home/alan/Documents/Dataset_1/brain-tumor-detection-dataset/Br35H-Mask-RCNN/test/images'
    empirical_validation(best_model, directory_path, k=3)

if __name__ == "__main__":
    main()
# Out:
# Evaluating layer at index: 100
# Collected features for 500 samples from layer at index '100'.
# complete
# Overall correlation score for the target layer: 0.06284209811872503
# Evaluating layer at index: 120
# Collected features for 500 samples from layer at index '120'.
# complete
# Overall correlation score for the target layer: 0.07924701943947501
# Evaluating layer at index: 140
# Collected features for 500 samples from layer at index '140'.
# complete
# Overall correlation score for the target layer: 0.09886737255287333
# Evaluating layer at index: 160
# Collected features for 500 samples from layer at index '160'.
# complete
# Overall correlation score for the target layer: 0.058628296572787696
# Evaluating layer at index: 180
# Collected features for 500 samples from layer at index '180'.
# complete
# Overall correlation score for the target layer: 0.05617642212645295
# Evaluating layer at index: 200
# Collected features for 500 samples from layer at index '200'.
# complete
# Overall correlation score for the target layer: 0.06358606221000337
# Evaluating layer at index: 220
# Collected features for 500 samples from layer at index '220'.
# complete
# Overall correlation score for the target layer: 0.06220296862366806
# Evaluating layer at index: 240
# Collected features for 500 samples from layer at index '240'.
# complete
# Overall correlation score for the target layer: 0.06402468367710817
# Evaluating layer at index: 260
# Collected features for 500 samples from layer at index '260'.
# complete
# Overall correlation score for the target layer: 0.06069415498332115
# Evaluating layer at index: 280
# Collected features for 500 samples from layer at index '280'.
# complete
# Overall correlation score for the target layer: 0.06490078748812077
# Layer Scores:
# Layer 100: 0.06284209811872503
# Layer 120: 0.07924701943947501
# Layer 140: 0.09886737255287333
# Layer 160: 0.058628296572787696
# Layer 180: 0.05617642212645295
# Layer 200: 0.06358606221000337
# Layer 220: 0.06220296862366806
# Layer 240: 0.06402468367710817
# Layer 260: 0.06069415498332115
# Layer 280: 0.06490078748812077
# Best layer index: 140 with score: 0.09886737255287333
# Collected features for 500 samples from layer at index '140'.
# complete
# {'model_prediction': 0, 'confidence_score': 0.047083545476198196, 'bounding_box': array([    0.29522,     0.44679,     0.37941,     0.52743]), 'nearest_neighbors': ['y82.jpg', 'y196.jpg', 'y263.jpg'], 'distances': array([[      82201,  1.1831e+05,  1.2104e+05]], dtype=float32), 'filename': 'y726.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.034216366708278656, 'bounding_box': array([    0.26453,     0.34471,     0.32458,     0.29547]), 'nearest_neighbors': ['y120.jpg', 'y125.jpg', 'y65.jpg'], 'distances': array([[      85104,       85312,       88824]], dtype=float32), 'filename': 'y706.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.38071495294570923, 'bounding_box': array([    0.69016,     0.23499,     0.22606,     0.28076]), 'nearest_neighbors': ['y103.jpg', 'y138.jpg', 'y132.jpg'], 'distances': array([[      60499,       94272,       96820]], dtype=float32), 'filename': 'y748.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.00158164172898978, 'bounding_box': array([    0.81289,    0.029481,     0.37039,    0.059232]), 'nearest_neighbors': ['y135.jpg', 'y133.jpg', 'y63.jpg'], 'distances': array([[      73848,  1.5217e+05,  1.6281e+05]], dtype=float32), 'filename': 'y782.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0010196887888014317, 'bounding_box': array([    0.29392,     0.01745,     0.33563,    0.034804]), 'nearest_neighbors': ['y130.jpg', 'y123.jpg', 'y140.jpg'], 'distances': array([[      67186,       91004,       95887]], dtype=float32), 'filename': 'y777.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.3349233865737915, 'bounding_box': array([    0.28169,     0.53506,     0.24186,     0.22072]), 'nearest_neighbors': ['y137.jpg', 'y139.jpg', 'y102.jpg'], 'distances': array([[      55849,  1.0383e+05,  1.0384e+05]], dtype=float32), 'filename': 'y784.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.01232866570353508, 'bounding_box': array([    0.36488,     0.25389,     0.18988,     0.27064]), 'nearest_neighbors': ['y127.jpg', 'y71.jpg', 'y69.jpg'], 'distances': array([[ 1.1189e+05,  1.5328e+05,  1.5812e+05]], dtype=float32), 'filename': 'y774.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.012457335367798805, 'bounding_box': array([    0.31168,     0.21836,     0.15286,      0.1222]), 'nearest_neighbors': ['y116.jpg', 'y193.jpg', 'y225.jpg'], 'distances': array([[      67437,  1.1151e+05,   1.125e+05]], dtype=float32), 'filename': 'y761.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.037666529417037964, 'bounding_box': array([    0.36779,     0.70843,      0.4731,      0.4085]), 'nearest_neighbors': ['y136.jpg', 'y79.jpg', 'y180.jpg'], 'distances': array([[      98312,  1.1993e+05,  1.2568e+05]], dtype=float32), 'filename': 'y783.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.2390187531709671, 'bounding_box': array([    0.70304,      0.5223,     0.23616,     0.19419]), 'nearest_neighbors': ['y348.jpg', 'y58.jpg', 'y200.jpg'], 'distances': array([[ 1.2169e+05,  1.2254e+05,  1.3137e+05]], dtype=float32), 'filename': 'y800.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.5056341886520386, 'bounding_box': array([    0.39276,     0.65982,     0.33293,     0.41171]), 'nearest_neighbors': ['y106.jpg', 'y66.jpg', 'y112.jpg'], 'distances': array([[ 1.3721e+05,  1.5028e+05,  1.5419e+05]], dtype=float32), 'filename': 'y763.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.10396315157413483, 'bounding_box': array([    0.66685,     0.57457,     0.38069,     0.51142]), 'nearest_neighbors': ['y117.jpg', 'y189.jpg', 'y107.jpg'], 'distances': array([[  1.053e+05,  1.3191e+05,  1.3811e+05]], dtype=float32), 'filename': 'y762.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.23129025101661682, 'bounding_box': array([    0.23289,     0.45031,     0.28298,     0.26153]), 'nearest_neighbors': ['y126.jpg', 'y185.jpg', 'y246.jpg'], 'distances': array([[ 1.0364e+05,  1.2756e+05,  1.3344e+05]], dtype=float32), 'filename': 'y773.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.004357913043349981, 'bounding_box': array([     0.3046,     0.22026,     0.39335,     0.25486]), 'nearest_neighbors': ['y101.jpg', 'y111.jpg', 'y66.jpg'], 'distances': array([[      55359,  1.0294e+05,  1.0654e+05]], dtype=float32), 'filename': 'y746.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.12077029049396515, 'bounding_box': array([    0.62396,     0.85585,     0.24551,      0.2342]), 'nearest_neighbors': ['y85.jpg', 'y102.jpg', 'y129.jpg'], 'distances': array([[      47430,       75421,       77070]], dtype=float32), 'filename': 'y728.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.5940195322036743, 'bounding_box': array([    0.69648,      0.5518,     0.38038,     0.26412]), 'nearest_neighbors': ['y95.jpg', 'y165.jpg', 'y239.jpg'], 'distances': array([[      92199,  1.1712e+05,  1.1717e+05]], dtype=float32), 'filename': 'y738.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0054366313852369785, 'bounding_box': array([    0.29162,     0.44903,      0.3813,     0.52121]), 'nearest_neighbors': ['y82.jpg', 'y266.jpg', 'y263.jpg'], 'distances': array([[      96278,  1.3066e+05,  1.3094e+05]], dtype=float32), 'filename': 'y786.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.04691562056541443, 'bounding_box': array([     0.7845,     0.30728,     0.18192,     0.13294]), 'nearest_neighbors': ['y68.jpg', 'y143.jpg', 'y139.jpg'], 'distances': array([[      56866,       86067,       87468]], dtype=float32), 'filename': 'y710.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.03889603540301323, 'bounding_box': array([    0.27912,     0.49198,      0.2596,     0.20347]), 'nearest_neighbors': ['y113.jpg', 'y180.jpg', 'y88.jpg'], 'distances': array([[      64974,       79200,       80613]], dtype=float32), 'filename': 'y705.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.3357115685939789, 'bounding_box': array([    0.28828,     0.45824,     0.39948,     0.42727]), 'nearest_neighbors': ['y64.jpg', 'y225.jpg', 'y162.jpg'], 'distances': array([[  1.341e+05,  1.3888e+05,  1.4089e+05]], dtype=float32), 'filename': 'y704.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.03612301126122475, 'bounding_box': array([    0.39768,     0.76021,     0.36651,     0.27417]), 'nearest_neighbors': ['y106.jpg', 'y121.jpg', 'y119.jpg'], 'distances': array([[ 1.2638e+05,  1.2662e+05,  1.2787e+05]], dtype=float32), 'filename': 'y702.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0010503488592803478, 'bounding_box': array([    0.75841,    0.018813,     0.36295,    0.037512]), 'nearest_neighbors': ['y72.jpg', 'y129.jpg', 'y102.jpg'], 'distances': array([[      56370,       82053,       82695]], dtype=float32), 'filename': 'y714.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.6040900349617004, 'bounding_box': array([    0.59833,     0.30552,     0.17189,     0.14624]), 'nearest_neighbors': ['y94.jpg', 'y102.jpg', 'y141.jpg'], 'distances': array([[      49862,       66467,       69172]], dtype=float32), 'filename': 'y737.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.35373425483703613, 'bounding_box': array([    0.74948,     0.63288,      0.1975,     0.16159]), 'nearest_neighbors': ['y124.jpg', 'y111.jpg', 'y81.jpg'], 'distances': array([[      70683,       83397,  1.1253e+05]], dtype=float32), 'filename': 'y771.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.27004295587539673, 'bounding_box': array([    0.38252,     0.66813,     0.44341,     0.47621]), 'nearest_neighbors': ['y231.jpg', 'y87.jpg', 'y180.jpg'], 'distances': array([[      99794,  1.0283e+05,  1.0819e+05]], dtype=float32), 'filename': 'y730.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.05362908914685249, 'bounding_box': array([    0.61783,     0.76856,     0.30844,     0.28154]), 'nearest_neighbors': ['y139.jpg', 'y102.jpg', 'y94.jpg'], 'distances': array([[      39681,       79886,       84293]], dtype=float32), 'filename': 'y787.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.4112448990345001, 'bounding_box': array([     0.7152,     0.30105,      0.1802,     0.18673]), 'nearest_neighbors': ['y110.jpg', 'y129.jpg', 'y102.jpg'], 'distances': array([[      52630,       60948,       70281]], dtype=float32), 'filename': 'y755.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.864925742149353, 'bounding_box': array([    0.73866,      0.6182,     0.31728,     0.33642]), 'nearest_neighbors': ['y86.jpg', 'y68.jpg', 'y130.jpg'], 'distances': array([[ 1.0526e+05,  1.2046e+05,  1.2269e+05]], dtype=float32), 'filename': 'y729.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.3750963509082794, 'bounding_box': array([    0.40239,     0.34474,     0.31888,     0.38314]), 'nearest_neighbors': ['y287.jpg', 'y305.jpg', 'y309.jpg'], 'distances': array([[      70833,  1.0699e+05,  1.0775e+05]], dtype=float32), 'filename': 'y798.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.2825039327144623, 'bounding_box': array([    0.58126,     0.49916,     0.11567,      0.1314]), 'nearest_neighbors': ['y94.jpg', 'y143.jpg', 'y68.jpg'], 'distances': array([[ 1.1159e+05,  1.1417e+05,  1.1833e+05]], dtype=float32), 'filename': 'y759.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.7721964716911316, 'bounding_box': array([    0.53581,     0.58191,     0.16749,      0.1557]), 'nearest_neighbors': ['y93.jpg', 'y139.jpg', 'y92.jpg'], 'distances': array([[      51092,  1.3022e+05,  1.3531e+05]], dtype=float32), 'filename': 'y736.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.001497649122029543, 'bounding_box': array([    0.35975,     0.66762,     0.25309,     0.38019]), 'nearest_neighbors': ['y134.jpg', 'y133.jpg', 'y135.jpg'], 'distances': array([[ 1.0709e+05,  1.5589e+05,   1.779e+05]], dtype=float32), 'filename': 'y781.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.4290185272693634, 'bounding_box': array([    0.31262,     0.45883,     0.18375,     0.16529]), 'nearest_neighbors': ['y138.jpg', 'y123.jpg', 'y140.jpg'], 'distances': array([[      97146,       99137,  1.0003e+05]], dtype=float32), 'filename': 'y745.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.09295844286680222, 'bounding_box': array([     0.6903,     0.72004,     0.33287,     0.35963]), 'nearest_neighbors': ['y285.jpg', 'y57.jpg', 'y326.jpg'], 'distances': array([[ 1.2494e+05,  1.3485e+05,   1.437e+05]], dtype=float32), 'filename': 'y799.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.4240385890007019, 'bounding_box': array([    0.27495,     0.66144,     0.23816,     0.21791]), 'nearest_neighbors': ['y63.jpg', 'y104.jpg', 'y116.jpg'], 'distances': array([[      89699,  1.2474e+05,  1.3528e+05]], dtype=float32), 'filename': 'y703.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.7940201163291931, 'bounding_box': array([    0.44602,     0.55409,     0.24135,     0.30968]), 'nearest_neighbors': ['y76.jpg', 'y130.jpg', 'y140.jpg'], 'distances': array([[      59751,  1.1562e+05,   1.165e+05]], dtype=float32), 'filename': 'y721.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.40282437205314636, 'bounding_box': array([    0.27025,      0.4076,     0.26016,     0.27368]), 'nearest_neighbors': ['y75.jpg', 'y140.jpg', 'y73.jpg'], 'distances': array([[      92074,  1.1282e+05,  1.1695e+05]], dtype=float32), 'filename': 'y720.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.01856103725731373, 'bounding_box': array([    0.35573,     0.33024,     0.14848,     0.14447]), 'nearest_neighbors': ['y113.jpg', 'y242.jpg', 'y78.jpg'], 'distances': array([[      70724,       72608,       72909]], dtype=float32), 'filename': 'y741.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.62806236743927, 'bounding_box': array([    0.23014,     0.54542,     0.24778,     0.32321]), 'nearest_neighbors': ['y54.jpg', 'y126.jpg', 'y71.jpg'], 'distances': array([[ 1.6784e+05,  1.7264e+05,  1.7314e+05]], dtype=float32), 'filename': 'y797.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.8542268872261047, 'bounding_box': array([    0.67138,     0.57655,     0.24567,     0.29082]), 'nearest_neighbors': ['y107.jpg', 'y132.jpg', 'y105.jpg'], 'distances': array([[      67105,       99214,       99937]], dtype=float32), 'filename': 'y752.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.011403864249587059, 'bounding_box': array([    0.29168,     0.49362,     0.24152,     0.19774]), 'nearest_neighbors': ['y113.jpg', 'y180.jpg', 'y78.jpg'], 'distances': array([[      59042,       76724,       78098]], dtype=float32), 'filename': 'y758.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.2538287043571472, 'bounding_box': array([    0.25766,     0.35182,     0.29201,     0.30447]), 'nearest_neighbors': ['y125.jpg', 'y120.jpg', 'y65.jpg'], 'distances': array([[      77840,       81338,       86426]], dtype=float32), 'filename': 'y772.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.05211310461163521, 'bounding_box': array([    0.35911,      0.7351,     0.35308,     0.36143]), 'nearest_neighbors': ['y79.jpg', 'y98.jpg', 'y85.jpg'], 'distances': array([[      63083,       71833,       79296]], dtype=float32), 'filename': 'y723.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0020955607760697603, 'bounding_box': array([    0.27687,     0.74648,      0.3553,     0.38732]), 'nearest_neighbors': ['y139.jpg', 'y114.jpg', 'y102.jpg'], 'distances': array([[      89347,       96252,       99078]], dtype=float32), 'filename': 'y794.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0061325207352638245, 'bounding_box': array([    0.21075,     0.28375,     0.28808,     0.23015]), 'nearest_neighbors': ['y96.jpg', 'y102.jpg', 'y68.jpg'], 'distances': array([[      56146,       88228,       88535]], dtype=float32), 'filename': 'y739.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.001610592007637024, 'bounding_box': array([    0.94018,     0.97352,    0.046909,    0.045994]), 'nearest_neighbors': ['y143.jpg', 'y94.jpg', 'y68.jpg'], 'distances': array([[      37720,       79270,       79548]], dtype=float32), 'filename': 'y791.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.005110869649797678, 'bounding_box': array([    0.35991,     0.33067,    0.098917,     0.14851]), 'nearest_neighbors': ['y97.jpg', 'y79.jpg', 'y98.jpg'], 'distances': array([[      78172,   1.019e+05,  1.0531e+05]], dtype=float32), 'filename': 'y740.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.18055228888988495, 'bounding_box': array([    0.41213,     0.70487,      0.3956,     0.38455]), 'nearest_neighbors': ['y133.jpg', 'y332.jpg', 'y225.jpg'], 'distances': array([[      86676,  1.4197e+05,  1.4268e+05]], dtype=float32), 'filename': 'y780.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.07101898640394211, 'bounding_box': array([    0.34629,     0.50615,     0.33237,     0.17965]), 'nearest_neighbors': ['y88.jpg', 'y180.jpg', 'y109.jpg'], 'distances': array([[      84243,       97527,       99903]], dtype=float32), 'filename': 'y754.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.00518018426373601, 'bounding_box': array([    0.57072,     0.40427,     0.21266,     0.20662]), 'nearest_neighbors': ['y94.jpg', 'y102.jpg', 'y68.jpg'], 'distances': array([[      80181,       81823,       81993]], dtype=float32), 'filename': 'y795.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0018591673579066992, 'bounding_box': array([    0.47989,     0.02485,     0.29824,    0.049514]), 'nearest_neighbors': ['y140.jpg', 'y123.jpg', 'y100.jpg'], 'distances': array([[      39434,       86327,       98875]], dtype=float32), 'filename': 'y788.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0016697309911251068, 'bounding_box': array([    0.48734,     0.51278,     0.61147,     0.74803]), 'nearest_neighbors': ['y138.jpg', 'y100.jpg', 'y98.jpg'], 'distances': array([[      32162,       88264,       95772]], dtype=float32), 'filename': 'y785.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.24328427016735077, 'bounding_box': array([    0.30492,     0.38463,      0.2849,     0.36401]), 'nearest_neighbors': ['y56.jpg', 'y103.jpg', 'y138.jpg'], 'distances': array([[      78925,  1.0414e+05,  1.0489e+05]], dtype=float32), 'filename': 'y707.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.1412934511899948, 'bounding_box': array([    0.51112,     0.30811,     0.12116,      0.1603]), 'nearest_neighbors': ['y69.jpg', 'y155.jpg', 'y216.jpg'], 'distances': array([[      81965,  1.2042e+05,  1.2101e+05]], dtype=float32), 'filename': 'y711.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.22098946571350098, 'bounding_box': array([    0.55528,     0.59604,     0.15879,     0.21961]), 'nearest_neighbors': ['y132.jpg', 'y105.jpg', 'y103.jpg'], 'distances': array([[      43365,       43645,       92782]], dtype=float32), 'filename': 'y779.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.08940672129392624, 'bounding_box': array([    0.42742,      0.6724,     0.35188,     0.34537]), 'nearest_neighbors': ['y122.jpg', 'y119.jpg', 'y59.jpg'], 'distances': array([[      93093,  1.1292e+05,  1.1573e+05]], dtype=float32), 'filename': 'y768.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.001561085577122867, 'bounding_box': array([    0.26134,      0.6303,     0.20025,     0.12539]), 'nearest_neighbors': ['y111.jpg', 'y124.jpg', 'y101.jpg'], 'distances': array([[      50061,       93571,       96765]], dtype=float32), 'filename': 'y756.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.39683133363723755, 'bounding_box': array([    0.40713,     0.76158,     0.39921,     0.33715]), 'nearest_neighbors': ['y71.jpg', 'y226.jpg', 'y205.jpg'], 'distances': array([[ 1.0448e+05,   1.416e+05,  1.4287e+05]], dtype=float32), 'filename': 'y713.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.4073149859905243, 'bounding_box': array([      0.727,     0.25247,     0.30104,     0.30918]), 'nearest_neighbors': ['y112.jpg', 'y66.jpg', 'y101.jpg'], 'distances': array([[      76270,       77596,       94129]], dtype=float32), 'filename': 'y757.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.9414944052696228, 'bounding_box': array([    0.67094,     0.43257,     0.25716,     0.23365]), 'nearest_neighbors': ['y108.jpg', 'y73.jpg', 'y74.jpg'], 'distances': array([[ 1.3263e+05,  1.3696e+05,  1.4414e+05]], dtype=float32), 'filename': 'y753.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.03629349172115326, 'bounding_box': array([    0.42872,     0.16064,     0.13419,      0.1452]), 'nearest_neighbors': ['y9.jpg', 'y144.jpg', 'y109.jpg'], 'distances': array([[ 1.4945e+05,  1.4952e+05,  1.5432e+05]], dtype=float32), 'filename': 'y718.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.2520352900028229, 'bounding_box': array([    0.66123,     0.65526,     0.47793,     0.52161]), 'nearest_neighbors': ['y106.jpg', 'y121.jpg', 'y313.jpg'], 'distances': array([[ 1.0786e+05,  1.1367e+05,  1.4148e+05]], dtype=float32), 'filename': 'y767.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.05439835041761398, 'bounding_box': array([    0.25334,     0.35097,     0.30175,     0.29955]), 'nearest_neighbors': ['y120.jpg', 'y125.jpg', 'y65.jpg'], 'distances': array([[      74009,       80451,       90103]], dtype=float32), 'filename': 'y766.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.012321055866777897, 'bounding_box': array([    0.29946,      0.3608,     0.30666,     0.25005]), 'nearest_neighbors': ['y91.jpg', 'y13.jpg', 'y119.jpg'], 'distances': array([[      90716,  1.3112e+05,  1.4346e+05]], dtype=float32), 'filename': 'y735.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.01784975826740265, 'bounding_box': array([     0.3881,     0.64425,     0.22579,     0.22339]), 'nearest_neighbors': ['y78.jpg', 'y129.jpg', 'y102.jpg'], 'distances': array([[      39729,       66408,       69385]], dtype=float32), 'filename': 'y722.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.4978807270526886, 'bounding_box': array([    0.26402,     0.69343,      0.2801,     0.28899]), 'nearest_neighbors': ['y120.jpg', 'y101.jpg', 'y138.jpg'], 'distances': array([[ 1.1744e+05,  1.2438e+05,  1.3195e+05]], dtype=float32), 'filename': 'y796.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.1805301159620285, 'bounding_box': array([    0.43114,     0.30369,     0.25047,     0.23535]), 'nearest_neighbors': ['y141.jpg', 'y102.jpg', 'y129.jpg'], 'distances': array([[      35863,       53778,       68923]], dtype=float32), 'filename': 'y789.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.004829677753150463, 'bounding_box': array([    0.22633,     0.34163,     0.21688,     0.19983]), 'nearest_neighbors': ['y119.jpg', 'y169.jpg', 'y125.jpg'], 'distances': array([[      64774,  1.1058e+05,   1.108e+05]], dtype=float32), 'filename': 'y765.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.5324442386627197, 'bounding_box': array([    0.67177,     0.60302,     0.14561,     0.17129]), 'nearest_neighbors': ['y99.jpg', 'y128.jpg', 'y16.jpg'], 'distances': array([[      79653,  1.2369e+05,  1.2787e+05]], dtype=float32), 'filename': 'y743.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.1416568160057068, 'bounding_box': array([    0.35462,     0.72543,     0.32584,     0.37118]), 'nearest_neighbors': ['y98.jpg', 'y79.jpg', 'y85.jpg'], 'distances': array([[      58731,       73576,       91514]], dtype=float32), 'filename': 'y742.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.15549591183662415, 'bounding_box': array([    0.56853,      0.2579,    0.085384,    0.095476]), 'nearest_neighbors': ['y118.jpg', 'y68.jpg', 'y138.jpg'], 'distances': array([[      32658,       98012,       99844]], dtype=float32), 'filename': 'y764.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.8298495411872864, 'bounding_box': array([    0.29348,     0.36505,     0.28395,     0.26696]), 'nearest_neighbors': ['y74.jpg', 'y8.jpg', 'y104.jpg'], 'distances': array([[ 1.1374e+05,  1.2333e+05,   1.255e+05]], dtype=float32), 'filename': 'y717.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.02817680686712265, 'bounding_box': array([    0.36239,     0.66216,     0.44421,      0.4757]), 'nearest_neighbors': ['y89.jpg', 'y98.jpg', 'y78.jpg'], 'distances': array([[      81664,       88133,       88894]], dtype=float32), 'filename': 'y732.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.006273037753999233, 'bounding_box': array([    0.33233,      0.7516,     0.33188,        0.24]), 'nearest_neighbors': ['y275.jpg', 'y205.jpg', 'y69.jpg'], 'distances': array([[ 1.4635e+05,  1.4803e+05,  1.5181e+05]], dtype=float32), 'filename': 'y719.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.025227969512343407, 'bounding_box': array([    0.47788,     0.65282,     0.41572,     0.30775]), 'nearest_neighbors': ['y128.jpg', 'y200.jpg', 'y68.jpg'], 'distances': array([[      39549,  1.0552e+05,  1.1135e+05]], dtype=float32), 'filename': 'y770.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0011174280662089586, 'bounding_box': array([    0.45868,     0.64487,      0.3474,     0.24279]), 'nearest_neighbors': ['y129.jpg', 'y102.jpg', 'y110.jpg'], 'distances': array([[      34237,       45351,       62028]], dtype=float32), 'filename': 'y776.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.5833354592323303, 'bounding_box': array([    0.69457,     0.74324,     0.30365,     0.29934]), 'nearest_neighbors': ['y104.jpg', 'y248.jpg', 'y63.jpg'], 'distances': array([[ 1.0944e+05,  1.2453e+05,  1.2821e+05]], dtype=float32), 'filename': 'y749.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.2570652365684509, 'bounding_box': array([    0.47704,     0.65099,     0.43035,     0.31346]), 'nearest_neighbors': ['y128.jpg', 'y200.jpg', 'y269.jpg'], 'distances': array([[      38676,  1.0714e+05,  1.1781e+05]], dtype=float32), 'filename': 'y775.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.40882188081741333, 'bounding_box': array([     0.7199,     0.24833,     0.28796,     0.28863]), 'nearest_neighbors': ['y66.jpg', 'y112.jpg', 'y125.jpg'], 'distances': array([[      74160,       82005,       96429]], dtype=float32), 'filename': 'y708.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.45469585061073303, 'bounding_box': array([    0.67018,     0.63993,      0.4945,     0.51429]), 'nearest_neighbors': ['y106.jpg', 'y121.jpg', 'y313.jpg'], 'distances': array([[ 1.0066e+05,  1.1234e+05,  1.3945e+05]], dtype=float32), 'filename': 'y751.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.01835567131638527, 'bounding_box': array([    0.22396,      0.3983,     0.23832,     0.19979]), 'nearest_neighbors': ['y62.jpg', 'y58.jpg', 'y68.jpg'], 'distances': array([[      96902,  1.0917e+05,  1.1864e+05]], dtype=float32), 'filename': 'y701.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.004633914679288864, 'bounding_box': array([     0.4827,    0.017041,     0.28622,     0.03401]), 'nearest_neighbors': ['y80.jpg', 'y225.jpg', 'y162.jpg'], 'distances': array([[      84023,  1.0626e+05,  1.0862e+05]], dtype=float32), 'filename': 'y724.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0030170525424182415, 'bounding_box': array([     0.6302,     0.57691,     0.32064,     0.45789]), 'nearest_neighbors': ['y123.jpg', 'y140.jpg', 'y113.jpg'], 'distances': array([[      37401,       80309,       81164]], dtype=float32), 'filename': 'y769.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.13218776881694794, 'bounding_box': array([    0.35379,     0.39156,     0.24944,     0.24319]), 'nearest_neighbors': ['y102.jpg', 'y141.jpg', 'y88.jpg'], 'distances': array([[      76914,       77779,       78047]], dtype=float32), 'filename': 'y727.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.037992529571056366, 'bounding_box': array([    0.67749,     0.33098,     0.41264,     0.41087]), 'nearest_neighbors': ['y84.jpg', 'y113.jpg', 'y109.jpg'], 'distances': array([[      69998,       73530,       81419]], dtype=float32), 'filename': 'y731.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.2236715704202652, 'bounding_box': array([    0.24538,     0.43222,     0.33117,     0.43071]), 'nearest_neighbors': ['y81.jpg', 'y124.jpg', 'y77.jpg'], 'distances': array([[      86128,  1.1125e+05,  1.1571e+05]], dtype=float32), 'filename': 'y725.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.22056320309638977, 'bounding_box': array([    0.20643,     0.40482,     0.23809,     0.20997]), 'nearest_neighbors': ['y144.jpg', 'y102.jpg', 'y94.jpg'], 'distances': array([[      66510,  1.0681e+05,  1.0879e+05]], dtype=float32), 'filename': 'y792.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.15939873456954956, 'bounding_box': array([    0.59046,     0.46596,     0.23367,     0.23115]), 'nearest_neighbors': ['y102.jpg', 'y129.jpg', 'y141.jpg'], 'distances': array([[      21530,       45920,       56702]], dtype=float32), 'filename': 'y747.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.917766809463501, 'bounding_box': array([    0.70002,     0.48925,     0.36472,     0.30009]), 'nearest_neighbors': ['y53.jpg', 'y332.jpg', 'y189.jpg'], 'distances': array([[ 1.2719e+05,  1.4098e+05,  1.4145e+05]], dtype=float32), 'filename': 'y793.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0014419462531805038, 'bounding_box': array([   0.021974,     0.46727,    0.044002,     0.36833]), 'nearest_neighbors': ['y139.jpg', 'y94.jpg', 'y143.jpg'], 'distances': array([[      75496,       81042,       82437]], dtype=float32), 'filename': 'y716.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.7348595261573792, 'bounding_box': array([    0.29533,     0.63058,    0.087533,    0.079207]), 'nearest_neighbors': ['y114.jpg', 'y129.jpg', 'y102.jpg'], 'distances': array([[      35280,       60389,       63535]], dtype=float32), 'filename': 'y760.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0025313592050224543, 'bounding_box': array([    0.63626,     0.50858,     0.73153,     0.76333]), 'nearest_neighbors': ['y70.jpg', 'y192.jpg', 'y162.jpg'], 'distances': array([[      85640,  1.0857e+05,  1.0915e+05]], dtype=float32), 'filename': 'y712.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.0011669147061184049, 'bounding_box': array([    0.52341,     0.39803,     0.33537,     0.26202]), 'nearest_neighbors': ['y144.jpg', 'y101.jpg', 'y139.jpg'], 'distances': array([[ 1.0067e+05,  1.0687e+05,  1.1069e+05]], dtype=float32), 'filename': 'y733.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.013310937210917473, 'bounding_box': array([    0.26918,     0.25369,     0.22159,     0.16703]), 'nearest_neighbors': ['y90.jpg', 'y125.jpg', 'y119.jpg'], 'distances': array([[      68340,  1.0668e+05,  1.0811e+05]], dtype=float32), 'filename': 'y734.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.9293348789215088, 'bounding_box': array([    0.46849,     0.80372,      0.3214,     0.23927]), 'nearest_neighbors': ['y67.jpg', 'y68.jpg', 'y128.jpg'], 'distances': array([[      44274,   1.198e+05,  1.2133e+05]], dtype=float32), 'filename': 'y709.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.48947688937187195, 'bounding_box': array([      0.556,     0.59634,     0.15897,     0.21663]), 'nearest_neighbors': ['y132.jpg', 'y105.jpg', 'y103.jpg'], 'distances': array([[      42645,       42732,       90986]], dtype=float32), 'filename': 'y750.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.39150139689445496, 'bounding_box': array([    0.67082,     0.49061,     0.32116,     0.34358]), 'nearest_neighbors': ['y100.jpg', 'y242.jpg', 'y113.jpg'], 'distances': array([[      74763,       82089,       87351]], dtype=float32), 'filename': 'y744.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.043480005115270615, 'bounding_box': array([    0.13514,     0.43534,     0.19449,     0.19282]), 'nearest_neighbors': ['y131.jpg', 'y58.jpg', 'y119.jpg'], 'distances': array([[  1.192e+05,  1.4466e+05,  1.5379e+05]], dtype=float32), 'filename': 'y778.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.09743068367242813, 'bounding_box': array([    0.27249,     0.45333,     0.16629,     0.13631]), 'nearest_neighbors': ['y73.jpg', 'y119.jpg', 'y75.jpg'], 'distances': array([[      80398,  1.1786e+05,  1.2285e+05]], dtype=float32), 'filename': 'y715.jpg'}
# {'model_prediction': 0, 'confidence_score': 0.5495622158050537, 'bounding_box': array([    0.22853,     0.50621,     0.32981,     0.24636]), 'nearest_neighbors': ['y142.jpg', 'y66.jpg', 'y101.jpg'], 'distances': array([[      99687,  1.3753e+05,  1.3898e+05]], dtype=float32), 'filename': 'y790.jpg'}
